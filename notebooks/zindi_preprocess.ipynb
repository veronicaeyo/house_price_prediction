# %%
import sys

sys.path.append('../scripts')

from first_preprocess import first_preprocess

# %%
X, y = first_preprocess(
    "../data/Housing_dataset_train.csv",
    "../data/Housing_dataset_test.csv",
    "../json/population_density.json",
)

# %%
X
# Out:
#        bedroom  bathroom  parking_space  is_lagos  is_mansion  comfort_ind  \
# 0          2.0       2.0            1.0         0           0     1.000000
# 1          4.0       2.0            4.0         0           0     2.000000
# 2          5.0       2.0            4.0         0           0     2.500000
# 3          4.0       5.0            6.0         0           0     0.800000
# 4          4.0       1.0            3.0         0           1     4.000000
# ...        ...       ...            ...       ...         ...          ...
# 10526      8.0       1.0            6.0         0           0     8.000000
# 10527      4.0       7.0            3.0         0           0     0.571429
# 10528      4.0       7.0            5.0         0           0     0.571429
# 10529      8.0       6.0            5.0         0           0     1.333333
# 10530      4.0       6.0            1.0         0           0     0.666667
#
#        size  comfort_by_size  population_density_level  loc_encoded  \
# 0       5.0         5.000000                         4         0.20
# 1      10.0        20.000000                         4         0.23
# 2      11.0        27.500000                         1         0.24
# 3      15.0        12.000000                         8         0.18
# 4       8.0        32.000000                        10         0.17
# ...     ...              ...                       ...          ...
# 10526  15.0       120.000000                        10         0.19
# 10527  14.0         8.000000                         6         0.23
# 10528  16.0         9.142857                         7         0.19
# 10529  19.0        25.333333                         7         0.19
# 10530  11.0         7.333333                         5         0.27
#
#        title_rank
# 0               5
# 1               2
# 2               8
# 3               6
# 4              10
# ...           ...
# 10526           8
# 10527           4
# 10528           2
# 10529           4
# 10530           3
#
# [10531 rows x 11 columns]

# %%
y
# Out:
# 0        1149999.565
# 1        1672416.689
# 2        2410306.756
# 3        2600700.898
# 4        1341750.867
#             ...
# 10526    2837199.086
# 10527    2367927.861
# 10528    2228516.471
# 10529    2406812.693
# 10530    3348918.718
# Name: price, Length: 10531, dtype: float64
